# %%
# Importamos las bibliotecas necesarias para manejar datos, hacer peticiones web y controlar el tiempo.
import re
import pandas as pd
import requests
import time

# %%
# Configuración inicial para usar en las clases.
genres = ["Drama"]
start_year = 2010
end_year = 2025
headers = {
#"X-RapidAPI-Key":"2a71737446mshd130aebe5b852b0p1d4674jsn1c93e1eccde5", #Mábel1
#"X-RapidAPI-Key":"8ce0139101msh32b3fde4a9a06cep1a18ddjsneec758e62128", #Mábel2
#"X-RapidAPI-Key":"af196f0478mshd90862dc657e127p18d90bjsn598fe178eab7", #Mábel3
#"X-RapidAPI-Key":"7afebd53f4msh5a5378a53b56ed5p11796bjsn19ceecfe1a26", #Marga1
#"X-RapidAPI-Key":"431e779057msh1f0c87c2937a329p125efcjsn45064e4b4925", #Marga2
#"X-RapidAPI-Key":"2a71737446mshd130aebe5b852b0p1d4674jsn1c93e1eccde5", #Marga3
#"X-RapidAPI-Key":"c5dae3bc7cmsh99f5150b0f14271p1276dfjsne7487416c47c", #Gloria1
#"X-RapidAPI-Key":"b0262d2945msh1f1577867db30c6p12fca9jsnc5eb4666d6bb", #Gloria2
"X-RapidAPI-Key":"1ef9312677msh54e21139cb02deap1a8f37jsn53623375f3fe", #Paola1
#"X-RapidAPI-Key": "28a3c3ab32msha5ca6e00170b6c7p197d01jsn44c7f725210a", #Paola2
#"X-RapidAPI-Key":"2583d39c0emshe321f51d17d9328p10cfb0jsn38ed4dc93da2", #Silvia1
#"X-RapidAPI-Key":"47608e078dmsha9428889aafcc0ap1afc77jsn6e04b24d521c", #Silvia2
"X-RapidAPI-Host":"moviesdatabase.p.rapidapi.com"
}

# %%
# Definimos una clase para manejar la recogida de datos de películas.
class MovieData:
    # Función inicial para configurar los parámetros básicos.
    def __init__(self, headers, genres, start_year, end_year):
        self.headers = headers  # Información para acceder a la API.
        self.genres = genres  # Tipos de películas que queremos buscar.
        self.start_year = start_year  # Año inicial.
        self.end_year = end_year  # Año final.
        self.sleep_time = 2  # Tiempo de espera inicial cuando la API limita las peticiones.

    # Función para buscar las películas en la API.
    def fetch_movies(self):
        movies_list = []  # Lista vacía para guardar los datos de las películas.
        # Bucles anidados para iterar por género, año y página.
        for genre in self.genres:
            for year in range(self.start_year, self.end_year + 1):
                for pagina in range(1, 51):
                    success = False  # Control para saber si la petición fue exitosa.
                    intentos = 0  # Contador de intentos de la petición.
                    while not success and intentos < 5:  # Si no es exitoso y tiene menos de 5 intentos.
                        url = f"https://moviesdatabase.p.rapidapi.com/titles?year={year}&genre={genre}&page={pagina}&limit=50"
                        response = requests.get(url, headers=self.headers)  # Hacemos la petición a la API.
                        # Comprobamos el código de estado de la respuesta.
                        if response.status_code == 200:
                            movies_data = response.json()["results"]  # Obtenemos los datos.
                            movies_list.extend(self.process_results(movies_data, genre))  # Procesamos y añadimos a la lista.
                            print(f"Recibiendo datos de {genre} en {year}, página {pagina}")
                            success = True  # Marcamos como exitoso.
                        elif response.status_code == 429:
                            print("Durmiendo... Demasiadas peticiones.")  # La API limita por demasiadas peticiones.
                            time.sleep(self.sleep_time * (2 ** intentos))  # Esperamos más tiempo en cada intento.
                            intentos += 1  # Incrementamos el contador de intentos.
                        else:
                            sms_error = response.json().get("error")  # Obtenemos mensaje de error.
                            print(f"Error tipo: {sms_error}")
                            break  # Salimos del bucle si hay otro tipo de error.
                        print("✅")
        return movies_list  # Devolvemos la lista de películas.

    # Función para procesar los datos obtenidos.
    def process_results(self, movies_data, genre):
        genre_movies = []  # Lista para guardar películas de un género.
        for data in movies_data:
            # Filtramos por tipo de título.
            if data["titleType"]["text"] in ["Movie", "Short"]:
                release_date = data.get("releaseDate")
                # Comprobamos que exista fecha de lanzamiento.
                if release_date and release_date.get("year") and release_date.get("month"):
                    movie_info = (
                        release_date.get("month"),
                        genre,
                        data["titleType"]["text"],
                        data["titleText"]["text"],
                        release_date.get("year"),
                        data["id"]
                    )
                    genre_movies.append(movie_info)  # Añadimos la info a la lista.
        return genre_movies  # Devolvemos las películas de un género.

# Clase para procesar y guardar los datos de las películas.
class MovieDataProcessor:
    def __init__(self, movies_list):
        self.movies_list = movies_list  # Lista de películas.

    # Función para convertir la lista en un dataframe.
    def to_dataframe(self):
        df = pd.DataFrame(self.movies_list, columnsy=["IMDB_ID", "Type", "Genre", "Movie_Title", "Release_Month", "Year"])
        return df  # Devolvemos el dataframe.

    # Función para guardar el dataframe en un archivo CSV.
    def save_to_csv(self, filename):
        df = self.to_dataframe()  # Obtenemos el dataframe.
        df.to_csv(filename, index=False)  # Guardamos el archivo sin índice.

# %%
# Crear instancias de las clases y usarlas.
recoleccion = MovieData(headers, genres, start_year, end_year)
movies = recoleccion.fetch_movies()
infiniteplay = MovieDataProcessor(movies)
# Out:
# Recibiendo datos de Drama en 2010, página 1
# ✅
# Recibiendo datos de Drama en 2010, página 2
# ✅
# Recibiendo datos de Drama en 2010, página 3
# ✅
# Recibiendo datos de Drama en 2010, página 4
# ✅
# Recibiendo datos de Drama en 2010, página 5
# ✅
# Recibiendo datos de Drama en 2010, página 6
# ✅
# Recibiendo datos de Drama en 2010, página 7
# ✅
# Recibiendo datos de Drama en 2010, página 8
# ✅
# Recibiendo datos de Drama en 2010, página 9
# ✅
# Recibiendo datos de Drama en 2010, página 10
# ✅
# Recibiendo datos de Drama en 2010, página 11
# ✅
# Recibiendo datos de Drama en 2010, página 12
# ✅
# Recibiendo datos de Drama en 2010, página 13
# ✅
# Recibiendo datos de Drama en 2010, página 14
# ✅
# Recibiendo datos de Drama en 2010, página 15
# ✅
# Recibiendo datos de Drama en 2010, página 16
# ✅
# Recibiendo datos de Drama en 2010, página 17
# ✅
# Recibiendo datos de Drama en 2010, página 18
# ✅
# Recibiendo datos de Drama en 2010, página 19
# ✅
# Recibiendo datos de Drama en 2010, página 20
# ✅
# Recibiendo datos de Drama en 2010, página 21
# ✅
# Recibiendo datos de Drama en 2010, página 22
# ✅
# Recibiendo datos de Drama en 2010, página 23
# ✅
# Recibiendo datos de Drama en 2010, página 24
# ✅
# Recibiendo datos de Drama en 2010, página 25
# ✅
# Recibiendo datos de Drama en 2010, página 26
# ✅
# Recibiendo datos de Drama en 2010, página 27
# ✅
# Recibiendo datos de Drama en 2010, página 28
# ✅
# Recibiendo datos de Drama en 2010, página 29
# ✅
# Recibiendo datos de Drama en 2010, página 30
# ✅
# Recibiendo datos de Drama en 2010, página 31
# ✅
# Recibiendo datos de Drama en 2010, página 32
# ✅
# Recibiendo datos de Drama en 2010, página 33
# ✅
# Recibiendo datos de Drama en 2010, página 34
# ✅
# Recibiendo datos de Drama en 2010, página 35
# ✅
# Recibiendo datos de Drama en 2010, página 36
# ✅
# Recibiendo datos de Drama en 2010, página 37
# ✅
# Recibiendo datos de Drama en 2010, página 38
# ✅
# Recibiendo datos de Drama en 2010, página 39
# ✅
# Recibiendo datos de Drama en 2010, página 40
# ✅
# Recibiendo datos de Drama en 2010, página 41
# ✅
# Recibiendo datos de Drama en 2010, página 42
# ✅
# Recibiendo datos de Drama en 2010, página 43
# ✅
# Recibiendo datos de Drama en 2010, página 44
# ✅
# Recibiendo datos de Drama en 2010, página 45
# ✅
# Recibiendo datos de Drama en 2010, página 46
# ✅
# Recibiendo datos de Drama en 2010, página 47
# ✅
# Recibiendo datos de Drama en 2010, página 48
# ✅
# Recibiendo datos de Drama en 2010, página 49
# ✅
# Recibiendo datos de Drama en 2010, página 50
# ✅
# Recibiendo datos de Drama en 2011, página 1
# ✅
# Recibiendo datos de Drama en 2011, página 2
# ✅
# Recibiendo datos de Drama en 2011, página 3
# ✅
# Recibiendo datos de Drama en 2011, página 4
# ✅
# Recibiendo datos de Drama en 2011, página 5
# ✅
# Recibiendo datos de Drama en 2011, página 6
# ✅
# Recibiendo datos de Drama en 2011, página 7
# ✅
# Recibiendo datos de Drama en 2011, página 8
# ✅
# Recibiendo datos de Drama en 2011, página 9
# ✅
# Recibiendo datos de Drama en 2011, página 10
# ✅
# Recibiendo datos de Drama en 2011, página 11
# ✅
# Recibiendo datos de Drama en 2011, página 12
# ✅
# Recibiendo datos de Drama en 2011, página 13
# ✅
# Recibiendo datos de Drama en 2011, página 14
# ✅
# Recibiendo datos de Drama en 2011, página 15
# ✅
# Recibiendo datos de Drama en 2011, página 16
# ✅
# Recibiendo datos de Drama en 2011, página 17
# ✅
# Recibiendo datos de Drama en 2011, página 18
# ✅
# Recibiendo datos de Drama en 2011, página 19
# ✅
# Recibiendo datos de Drama en 2011, página 20
# ✅
# Recibiendo datos de Drama en 2011, página 21
# ✅
# Recibiendo datos de Drama en 2011, página 22
# ✅
# Recibiendo datos de Drama en 2011, página 23
# ✅
# Recibiendo datos de Drama en 2011, página 24
# ✅
# Recibiendo datos de Drama en 2011, página 25
# ✅
# Recibiendo datos de Drama en 2011, página 26
# ✅
# Recibiendo datos de Drama en 2011, página 27
# ✅
# Recibiendo datos de Drama en 2011, página 28
# ✅
# Recibiendo datos de Drama en 2011, página 29
# ✅
# Recibiendo datos de Drama en 2011, página 30
# ✅
# Recibiendo datos de Drama en 2011, página 31
# ✅
# Recibiendo datos de Drama en 2011, página 32
# ✅
# Recibiendo datos de Drama en 2011, página 33
# ✅
# Recibiendo datos de Drama en 2011, página 34
# ✅
# Recibiendo datos de Drama en 2011, página 35
# ✅
# Recibiendo datos de Drama en 2011, página 36
# ✅
# Recibiendo datos de Drama en 2011, página 37
# ✅
# Recibiendo datos de Drama en 2011, página 38
# ✅
# Recibiendo datos de Drama en 2011, página 39
# ✅
# Recibiendo datos de Drama en 2011, página 40
# ✅
# Recibiendo datos de Drama en 2011, página 41
# ✅
# Recibiendo datos de Drama en 2011, página 42
# ✅
# Recibiendo datos de Drama en 2011, página 43
# ✅
# Recibiendo datos de Drama en 2011, página 44
# ✅
# Recibiendo datos de Drama en 2011, página 45
# ✅
# Recibiendo datos de Drama en 2011, página 46
# ✅
# Recibiendo datos de Drama en 2011, página 47
# ✅
# Recibiendo datos de Drama en 2011, página 48
# ✅
# Recibiendo datos de Drama en 2011, página 49
# ✅
# Recibiendo datos de Drama en 2011, página 50
# ✅
# Recibiendo datos de Drama en 2012, página 1
# ✅
# Recibiendo datos de Drama en 2012, página 2
# ✅
# Recibiendo datos de Drama en 2012, página 3
# ✅
# Recibiendo datos de Drama en 2012, página 4
# ✅
# Recibiendo datos de Drama en 2012, página 5
# ✅
# Recibiendo datos de Drama en 2012, página 6
# ✅
# Recibiendo datos de Drama en 2012, página 7
# ✅
# Recibiendo datos de Drama en 2012, página 8
# ✅
# Recibiendo datos de Drama en 2012, página 9
# ✅
# Recibiendo datos de Drama en 2012, página 10
# ✅
# Recibiendo datos de Drama en 2012, página 11
# ✅
# Recibiendo datos de Drama en 2012, página 12
# ✅
# Recibiendo datos de Drama en 2012, página 13
# ✅
# Recibiendo datos de Drama en 2012, página 14
# ✅
# Recibiendo datos de Drama en 2012, página 15
# ✅
# Recibiendo datos de Drama en 2012, página 16
# ✅
# Recibiendo datos de Drama en 2012, página 17
# ✅
# Recibiendo datos de Drama en 2012, página 18
# ✅
# Recibiendo datos de Drama en 2012, página 19
# ✅
# Recibiendo datos de Drama en 2012, página 20
# ✅
# Recibiendo datos de Drama en 2012, página 21
# ✅
# Recibiendo datos de Drama en 2012, página 22
# ✅
# Recibiendo datos de Drama en 2012, página 23
# ✅
# Recibiendo datos de Drama en 2012, página 24
# ✅
# Recibiendo datos de Drama en 2012, página 25
# ✅
# Recibiendo datos de Drama en 2012, página 26
# ✅
# Recibiendo datos de Drama en 2012, página 27
# ✅
# Recibiendo datos de Drama en 2012, página 28
# ✅
# Recibiendo datos de Drama en 2012, página 29
# ✅
# Recibiendo datos de Drama en 2012, página 30
# ✅
# Recibiendo datos de Drama en 2012, página 31
# ✅
# Recibiendo datos de Drama en 2012, página 32
# ✅
# Recibiendo datos de Drama en 2012, página 33
# ✅
# Recibiendo datos de Drama en 2012, página 34
# ✅
# Recibiendo datos de Drama en 2012, página 35
# ✅
# Recibiendo datos de Drama en 2012, página 36
# ✅
# Recibiendo datos de Drama en 2012, página 37
# ✅
# Recibiendo datos de Drama en 2012, página 38
# ✅
# Recibiendo datos de Drama en 2012, página 39
# ✅
# Recibiendo datos de Drama en 2012, página 40
# ✅
# Recibiendo datos de Drama en 2012, página 41
# ✅
# Recibiendo datos de Drama en 2012, página 42
# ✅
# Recibiendo datos de Drama en 2012, página 43
# ✅
# Recibiendo datos de Drama en 2012, página 44
# ✅
# Recibiendo datos de Drama en 2012, página 45
# ✅
# Recibiendo datos de Drama en 2012, página 46
# ✅
# Recibiendo datos de Drama en 2012, página 47
# ✅
# Recibiendo datos de Drama en 2012, página 48
# ✅
# Recibiendo datos de Drama en 2012, página 49
# ✅
# Recibiendo datos de Drama en 2012, página 50
# ✅
# Recibiendo datos de Drama en 2013, página 1
# ✅
# Recibiendo datos de Drama en 2013, página 2
# ✅
# Recibiendo datos de Drama en 2013, página 3
# ✅
# Recibiendo datos de Drama en 2013, página 4
# ✅
# Recibiendo datos de Drama en 2013, página 5
# ✅
# Recibiendo datos de Drama en 2013, página 6
# ✅
# Recibiendo datos de Drama en 2013, página 7
# ✅
# Recibiendo datos de Drama en 2013, página 8
# ✅
# Recibiendo datos de Drama en 2013, página 9
# ✅
# Recibiendo datos de Drama en 2013, página 10
# ✅
# Recibiendo datos de Drama en 2013, página 11
# ✅
# Recibiendo datos de Drama en 2013, página 12
# ✅
# Recibiendo datos de Drama en 2013, página 13
# ✅
# Recibiendo datos de Drama en 2013, página 14
# ✅
# Recibiendo datos de Drama en 2013, página 15
# ✅
# Recibiendo datos de Drama en 2013, página 16
# ✅
# Recibiendo datos de Drama en 2013, página 17
# ✅
# Recibiendo datos de Drama en 2013, página 18
# ✅
# Recibiendo datos de Drama en 2013, página 19
# ✅
# Recibiendo datos de Drama en 2013, página 20
# ✅
# Recibiendo datos de Drama en 2013, página 21
# ✅
# Recibiendo datos de Drama en 2013, página 22
# ✅
# Recibiendo datos de Drama en 2013, página 23
# ✅
# Recibiendo datos de Drama en 2013, página 24
# ✅
# Recibiendo datos de Drama en 2013, página 25
# ✅
# Recibiendo datos de Drama en 2013, página 26
# ✅
# Recibiendo datos de Drama en 2013, página 27
# ✅
# Recibiendo datos de Drama en 2013, página 28
# ✅
# Recibiendo datos de Drama en 2013, página 29
# ✅
# Recibiendo datos de Drama en 2013, página 30
# ✅
# Recibiendo datos de Drama en 2013, página 31
# ✅
# Recibiendo datos de Drama en 2013, página 32
# ✅
# Recibiendo datos de Drama en 2013, página 33
# ✅
# Recibiendo datos de Drama en 2013, página 34
# ✅
# Recibiendo datos de Drama en 2013, página 35
# ✅
# Recibiendo datos de Drama en 2013, página 36
# ✅
# Recibiendo datos de Drama en 2013, página 37
# ✅
# Recibiendo datos de Drama en 2013, página 38
# ✅
# Recibiendo datos de Drama en 2013, página 39
# ✅
# Recibiendo datos de Drama en 2013, página 40
# ✅
# Recibiendo datos de Drama en 2013, página 41
# ✅
# Recibiendo datos de Drama en 2013, página 42
# ✅
# Recibiendo datos de Drama en 2013, página 43
# ✅
# Recibiendo datos de Drama en 2013, página 44
# ✅
# Recibiendo datos de Drama en 2013, página 45
# ✅
# Recibiendo datos de Drama en 2013, página 46
# ✅
# Recibiendo datos de Drama en 2013, página 47
# ✅
# Recibiendo datos de Drama en 2013, página 48
# ✅
# Recibiendo datos de Drama en 2013, página 49
# ✅
# Recibiendo datos de Drama en 2013, página 50
# ✅
# Recibiendo datos de Drama en 2014, página 1
# ✅
# Recibiendo datos de Drama en 2014, página 2
# ✅
# Recibiendo datos de Drama en 2014, página 3
# ✅
# Recibiendo datos de Drama en 2014, página 4
# ✅
# Recibiendo datos de Drama en 2014, página 5
# ✅
# Recibiendo datos de Drama en 2014, página 6
# ✅
# Recibiendo datos de Drama en 2014, página 7
# ✅
# Recibiendo datos de Drama en 2014, página 8
# ✅
# Recibiendo datos de Drama en 2014, página 9
# ✅
# Recibiendo datos de Drama en 2014, página 10
# ✅
# Recibiendo datos de Drama en 2014, página 11
# ✅
# Recibiendo datos de Drama en 2014, página 12
# ✅
# Recibiendo datos de Drama en 2014, página 13
# ✅
# Recibiendo datos de Drama en 2014, página 14
# ✅
# Recibiendo datos de Drama en 2014, página 15
# ✅
# Recibiendo datos de Drama en 2014, página 16
# ✅
# Recibiendo datos de Drama en 2014, página 17
# ✅
# Recibiendo datos de Drama en 2014, página 18
# ✅
# Recibiendo datos de Drama en 2014, página 19
# ✅
# Recibiendo datos de Drama en 2014, página 20
# ✅
# Recibiendo datos de Drama en 2014, página 21
# ✅
# Recibiendo datos de Drama en 2014, página 22
# ✅
# Recibiendo datos de Drama en 2014, página 23
# ✅
# Recibiendo datos de Drama en 2014, página 24
# ✅
# Recibiendo datos de Drama en 2014, página 25
# ✅
# Recibiendo datos de Drama en 2014, página 26
# ✅
# Recibiendo datos de Drama en 2014, página 27
# ✅
# Recibiendo datos de Drama en 2014, página 28
# ✅
# Recibiendo datos de Drama en 2014, página 29
# ✅
# Recibiendo datos de Drama en 2014, página 30
# ✅
# Recibiendo datos de Drama en 2014, página 31
# ✅
# Recibiendo datos de Drama en 2014, página 32
# ✅
# Recibiendo datos de Drama en 2014, página 33
# ✅
# Recibiendo datos de Drama en 2014, página 34
# ✅
# Recibiendo datos de Drama en 2014, página 35
# ✅
# Recibiendo datos de Drama en 2014, página 36
# ✅
# Recibiendo datos de Drama en 2014, página 37
# ✅
# Recibiendo datos de Drama en 2014, página 38
# ✅
# Recibiendo datos de Drama en 2014, página 39
# ✅
# Recibiendo datos de Drama en 2014, página 40
# ✅
# Recibiendo datos de Drama en 2014, página 41
# ✅
# Recibiendo datos de Drama en 2014, página 42
# ✅
# Recibiendo datos de Drama en 2014, página 43
# ✅
# Recibiendo datos de Drama en 2014, página 44
# ✅
# Recibiendo datos de Drama en 2014, página 45
# ✅
# Recibiendo datos de Drama en 2014, página 46
# ✅
# Recibiendo datos de Drama en 2014, página 47
# ✅
# Recibiendo datos de Drama en 2014, página 48
# ✅
# Recibiendo datos de Drama en 2014, página 49
# ✅
# Recibiendo datos de Drama en 2014, página 50
# ✅
# Recibiendo datos de Drama en 2015, página 1
# ✅
# Recibiendo datos de Drama en 2015, página 2
# ✅
# Recibiendo datos de Drama en 2015, página 3
# ✅
# Recibiendo datos de Drama en 2015, página 4
# ✅
# Recibiendo datos de Drama en 2015, página 5
# ✅
# Recibiendo datos de Drama en 2015, página 6
# ✅
# Recibiendo datos de Drama en 2015, página 7
# ✅
# Recibiendo datos de Drama en 2015, página 8
# ✅
# Recibiendo datos de Drama en 2015, página 9
# ✅
# Recibiendo datos de Drama en 2015, página 10
# ✅
# Recibiendo datos de Drama en 2015, página 11
# ✅
# Recibiendo datos de Drama en 2015, página 12
# ✅
# Recibiendo datos de Drama en 2015, página 13
# ✅
# Recibiendo datos de Drama en 2015, página 14
# ✅
# Recibiendo datos de Drama en 2015, página 15
# ✅
# Recibiendo datos de Drama en 2015, página 16
# ✅
# Recibiendo datos de Drama en 2015, página 17
# ✅
# Recibiendo datos de Drama en 2015, página 18
# ✅
# Recibiendo datos de Drama en 2015, página 19
# ✅
# Recibiendo datos de Drama en 2015, página 20
# ✅
# Recibiendo datos de Drama en 2015, página 21
# ✅
# Recibiendo datos de Drama en 2015, página 22
# ✅
# Recibiendo datos de Drama en 2015, página 23
# ✅
# Recibiendo datos de Drama en 2015, página 24
# ✅
# Recibiendo datos de Drama en 2015, página 25
# ✅
# Recibiendo datos de Drama en 2015, página 26
# ✅
# Recibiendo datos de Drama en 2015, página 27
# ✅
# Recibiendo datos de Drama en 2015, página 28
# ✅
# Recibiendo datos de Drama en 2015, página 29
# ✅
# Recibiendo datos de Drama en 2015, página 30
# ✅
# Recibiendo datos de Drama en 2015, página 31
# ✅
# Recibiendo datos de Drama en 2015, página 32
# ✅
# Recibiendo datos de Drama en 2015, página 33
# ✅
# Recibiendo datos de Drama en 2015, página 34
# ✅
# Recibiendo datos de Drama en 2015, página 35
# ✅
# Recibiendo datos de Drama en 2015, página 36
# ✅
# Recibiendo datos de Drama en 2015, página 37
# ✅
# Recibiendo datos de Drama en 2015, página 38
# ✅
# Recibiendo datos de Drama en 2015, página 39
# ✅
# Recibiendo datos de Drama en 2015, página 40
# ✅
# Recibiendo datos de Drama en 2015, página 41
# ✅
# Recibiendo datos de Drama en 2015, página 42
# ✅
# Recibiendo datos de Drama en 2015, página 43
# ✅
# Recibiendo datos de Drama en 2015, página 44
# ✅
# Recibiendo datos de Drama en 2015, página 45
# ✅
# Recibiendo datos de Drama en 2015, página 46
# ✅
# Recibiendo datos de Drama en 2015, página 47
# ✅
# Recibiendo datos de Drama en 2015, página 48
# ✅
# Recibiendo datos de Drama en 2015, página 49
# ✅
# Recibiendo datos de Drama en 2015, página 50
# ✅
# Recibiendo datos de Drama en 2016, página 1
# ✅
# Recibiendo datos de Drama en 2016, página 2
# ✅
# Recibiendo datos de Drama en 2016, página 3
# ✅
# Recibiendo datos de Drama en 2016, página 4
# ✅
# Recibiendo datos de Drama en 2016, página 5
# ✅
# Recibiendo datos de Drama en 2016, página 6
# ✅
# Recibiendo datos de Drama en 2016, página 7
# ✅
# Recibiendo datos de Drama en 2016, página 8
# ✅
# Recibiendo datos de Drama en 2016, página 9
# ✅
# Recibiendo datos de Drama en 2016, página 10
# ✅
# Recibiendo datos de Drama en 2016, página 11
# ✅
# Recibiendo datos de Drama en 2016, página 12
# ✅
# Recibiendo datos de Drama en 2016, página 13
# ✅
# Recibiendo datos de Drama en 2016, página 14
# ✅
# Recibiendo datos de Drama en 2016, página 15
# ✅
# Recibiendo datos de Drama en 2016, página 16
# ✅
# Recibiendo datos de Drama en 2016, página 17
# ✅
# Recibiendo datos de Drama en 2016, página 18
# ✅
# Recibiendo datos de Drama en 2016, página 19
# ✅
# Recibiendo datos de Drama en 2016, página 20
# ✅
# Recibiendo datos de Drama en 2016, página 21
# ✅
# Recibiendo datos de Drama en 2016, página 22
# ✅
# Recibiendo datos de Drama en 2016, página 23
# ✅
# Recibiendo datos de Drama en 2016, página 24
# ✅
# Recibiendo datos de Drama en 2016, página 25
# ✅
# Recibiendo datos de Drama en 2016, página 26
# ✅
# Recibiendo datos de Drama en 2016, página 27
# ✅
# Recibiendo datos de Drama en 2016, página 28
# ✅
# Recibiendo datos de Drama en 2016, página 29
# ✅
# Recibiendo datos de Drama en 2016, página 30
# ✅
# Recibiendo datos de Drama en 2016, página 31
# ✅
# Recibiendo datos de Drama en 2016, página 32
# ✅
# Recibiendo datos de Drama en 2016, página 33
# ✅
# Recibiendo datos de Drama en 2016, página 34
# ✅
# Recibiendo datos de Drama en 2016, página 35
# ✅
# Recibiendo datos de Drama en 2016, página 36
# ✅
# Recibiendo datos de Drama en 2016, página 37
# ✅
# Recibiendo datos de Drama en 2016, página 38
# ✅
# Recibiendo datos de Drama en 2016, página 39
# ✅
# Recibiendo datos de Drama en 2016, página 40
# ✅
# Recibiendo datos de Drama en 2016, página 41
# ✅
# Recibiendo datos de Drama en 2016, página 42
# ✅
# Recibiendo datos de Drama en 2016, página 43
# ✅
# Recibiendo datos de Drama en 2016, página 44
# ✅
# Recibiendo datos de Drama en 2016, página 45
# ✅
# Recibiendo datos de Drama en 2016, página 46
# ✅
# Recibiendo datos de Drama en 2016, página 47
# ✅
# Recibiendo datos de Drama en 2016, página 48
# ✅
# Recibiendo datos de Drama en 2016, página 49
# ✅
# Recibiendo datos de Drama en 2016, página 50
# ✅
# Recibiendo datos de Drama en 2017, página 1
# ✅
# Recibiendo datos de Drama en 2017, página 2
# ✅
# Recibiendo datos de Drama en 2017, página 3
# ✅
# Recibiendo datos de Drama en 2017, página 4
# ✅
# Recibiendo datos de Drama en 2017, página 5
# ✅
# Recibiendo datos de Drama en 2017, página 6
# ✅
# Recibiendo datos de Drama en 2017, página 7
# ✅
# Recibiendo datos de Drama en 2017, página 8
# ✅
# Recibiendo datos de Drama en 2017, página 9
# ✅
# Recibiendo datos de Drama en 2017, página 10
# ✅
# Recibiendo datos de Drama en 2017, página 11
# ✅
# Recibiendo datos de Drama en 2017, página 12
# ✅
# Recibiendo datos de Drama en 2017, página 13
# ✅
# Recibiendo datos de Drama en 2017, página 14
# ✅
# Recibiendo datos de Drama en 2017, página 15
# ✅
# Recibiendo datos de Drama en 2017, página 16
# ✅
# Recibiendo datos de Drama en 2017, página 17
# ✅
# Recibiendo datos de Drama en 2017, página 18
# ✅
# Recibiendo datos de Drama en 2017, página 19
# ✅
# Recibiendo datos de Drama en 2017, página 20
# ✅
# Recibiendo datos de Drama en 2017, página 21
# ✅
# Recibiendo datos de Drama en 2017, página 22
# ✅
# Recibiendo datos de Drama en 2017, página 23
# ✅
# Recibiendo datos de Drama en 2017, página 24
# ✅
# Recibiendo datos de Drama en 2017, página 25
# ✅
# Recibiendo datos de Drama en 2017, página 26
# ✅
# Recibiendo datos de Drama en 2017, página 27
# ✅
# Recibiendo datos de Drama en 2017, página 28
# ✅
# Recibiendo datos de Drama en 2017, página 29
# ✅
# Recibiendo datos de Drama en 2017, página 30
# ✅
# Recibiendo datos de Drama en 2017, página 31
# ✅
# Recibiendo datos de Drama en 2017, página 32
# ✅
# Recibiendo datos de Drama en 2017, página 33
# ✅
# Recibiendo datos de Drama en 2017, página 34
# ✅
# Recibiendo datos de Drama en 2017, página 35
# ✅
# Recibiendo datos de Drama en 2017, página 36
# ✅
# Recibiendo datos de Drama en 2017, página 37
# ✅
# Recibiendo datos de Drama en 2017, página 38
# ✅
# Recibiendo datos de Drama en 2017, página 39
# ✅
# Recibiendo datos de Drama en 2017, página 40
# ✅
# Recibiendo datos de Drama en 2017, página 41
# ✅
# Recibiendo datos de Drama en 2017, página 42
# ✅
# Recibiendo datos de Drama en 2017, página 43
# ✅
# Recibiendo datos de Drama en 2017, página 44
# ✅
# Recibiendo datos de Drama en 2017, página 45
# ✅
# Recibiendo datos de Drama en 2017, página 46
# ✅
# Recibiendo datos de Drama en 2017, página 47
# ✅
# Recibiendo datos de Drama en 2017, página 48
# ✅
# Recibiendo datos de Drama en 2017, página 49
# ✅
# Recibiendo datos de Drama en 2017, página 50
# ✅
# Recibiendo datos de Drama en 2018, página 1
# ✅
# Recibiendo datos de Drama en 2018, página 2
# ✅
# Recibiendo datos de Drama en 2018, página 3
# ✅
# Recibiendo datos de Drama en 2018, página 4
# ✅
# Recibiendo datos de Drama en 2018, página 5
# ✅
# Recibiendo datos de Drama en 2018, página 6
# ✅
# Recibiendo datos de Drama en 2018, página 7
# ✅
# Recibiendo datos de Drama en 2018, página 8
# ✅
# Recibiendo datos de Drama en 2018, página 9
# ✅
# Recibiendo datos de Drama en 2018, página 10
# ✅
# Recibiendo datos de Drama en 2018, página 11
# ✅
# Recibiendo datos de Drama en 2018, página 12
# ✅
# Recibiendo datos de Drama en 2018, página 13
# ✅
# Recibiendo datos de Drama en 2018, página 14
# ✅
# Recibiendo datos de Drama en 2018, página 15
# ✅
# Recibiendo datos de Drama en 2018, página 16
# ✅
# Recibiendo datos de Drama en 2018, página 17
# ✅
# Recibiendo datos de Drama en 2018, página 18
# ✅
# Recibiendo datos de Drama en 2018, página 19
# ✅
# Recibiendo datos de Drama en 2018, página 20
# ✅
# Recibiendo datos de Drama en 2018, página 21
# ✅
# Recibiendo datos de Drama en 2018, página 22
# ✅
# Recibiendo datos de Drama en 2018, página 23
# ✅
# Recibiendo datos de Drama en 2018, página 24
# ✅
# Recibiendo datos de Drama en 2018, página 25
# ✅
# Recibiendo datos de Drama en 2018, página 26
# ✅
# Recibiendo datos de Drama en 2018, página 27
# ✅
# Recibiendo datos de Drama en 2018, página 28
# ✅
# Recibiendo datos de Drama en 2018, página 29
# ✅
# Recibiendo datos de Drama en 2018, página 30
# ✅
# Recibiendo datos de Drama en 2018, página 31
# ✅
# Recibiendo datos de Drama en 2018, página 32
# ✅
# Recibiendo datos de Drama en 2018, página 33
# ✅
# Recibiendo datos de Drama en 2018, página 34
# ✅
# Recibiendo datos de Drama en 2018, página 35
# ✅
# Recibiendo datos de Drama en 2018, página 36
# ✅
# Recibiendo datos de Drama en 2018, página 37
# ✅
# Recibiendo datos de Drama en 2018, página 38
# ✅
# Recibiendo datos de Drama en 2018, página 39
# ✅
# Recibiendo datos de Drama en 2018, página 40
# ✅
# Recibiendo datos de Drama en 2018, página 41
# ✅
# Recibiendo datos de Drama en 2018, página 42
# ✅
# Recibiendo datos de Drama en 2018, página 43
# ✅
# Recibiendo datos de Drama en 2018, página 44
# ✅
# Recibiendo datos de Drama en 2018, página 45
# ✅
# Recibiendo datos de Drama en 2018, página 46
# ✅
# Recibiendo datos de Drama en 2018, página 47
# ✅
# Recibiendo datos de Drama en 2018, página 48
# ✅
# Recibiendo datos de Drama en 2018, página 49
# ✅
# Recibiendo datos de Drama en 2018, página 50
# ✅
# Recibiendo datos de Drama en 2019, página 1
# ✅
# Recibiendo datos de Drama en 2019, página 2
# ✅
# Recibiendo datos de Drama en 2019, página 3
# ✅
# Recibiendo datos de Drama en 2019, página 4
# ✅
# Recibiendo datos de Drama en 2019, página 5
# ✅
# Recibiendo datos de Drama en 2019, página 6
# ✅
# Recibiendo datos de Drama en 2019, página 7
# ✅
# Recibiendo datos de Drama en 2019, página 8
# ✅
# Recibiendo datos de Drama en 2019, página 9
# ✅
# Recibiendo datos de Drama en 2019, página 10
# ✅
# Recibiendo datos de Drama en 2019, página 11
# ✅
# Recibiendo datos de Drama en 2019, página 12
# ✅
# Recibiendo datos de Drama en 2019, página 13
# ✅
# Recibiendo datos de Drama en 2019, página 14
# ✅
# Recibiendo datos de Drama en 2019, página 15
# ✅
# Recibiendo datos de Drama en 2019, página 16
# ✅
# Recibiendo datos de Drama en 2019, página 17
# ✅
# Recibiendo datos de Drama en 2019, página 18
# ✅
# Recibiendo datos de Drama en 2019, página 19
# ✅
# Recibiendo datos de Drama en 2019, página 20
# ✅
# Recibiendo datos de Drama en 2019, página 21
# ✅
# Recibiendo datos de Drama en 2019, página 22
# ✅
# Recibiendo datos de Drama en 2019, página 23
# ✅
# Recibiendo datos de Drama en 2019, página 24
# ✅
# Recibiendo datos de Drama en 2019, página 25
# ✅
# Recibiendo datos de Drama en 2019, página 26
# ✅
# Recibiendo datos de Drama en 2019, página 27
# ✅
# Recibiendo datos de Drama en 2019, página 28
# ✅
# Recibiendo datos de Drama en 2019, página 29
# ✅
# Recibiendo datos de Drama en 2019, página 30
# ✅
# Recibiendo datos de Drama en 2019, página 31
# ✅
# Recibiendo datos de Drama en 2019, página 32
# ✅
# Recibiendo datos de Drama en 2019, página 33
# ✅
# Recibiendo datos de Drama en 2019, página 34
# ✅
# Recibiendo datos de Drama en 2019, página 35
# ✅
# Recibiendo datos de Drama en 2019, página 36
# ✅
# Recibiendo datos de Drama en 2019, página 37
# ✅
# Recibiendo datos de Drama en 2019, página 38
# ✅
# Recibiendo datos de Drama en 2019, página 39
# ✅
# Recibiendo datos de Drama en 2019, página 40
# ✅
# Recibiendo datos de Drama en 2019, página 41
# ✅
# Recibiendo datos de Drama en 2019, página 42
# ✅
# Recibiendo datos de Drama en 2019, página 43
# ✅
# Recibiendo datos de Drama en 2019, página 44
# ✅
# Recibiendo datos de Drama en 2019, página 45
# ✅
# Recibiendo datos de Drama en 2019, página 46
# ✅
# Recibiendo datos de Drama en 2019, página 47
# ✅
# Recibiendo datos de Drama en 2019, página 48
# ✅
# Recibiendo datos de Drama en 2019, página 49
# ✅
# Recibiendo datos de Drama en 2019, página 50
# ✅
# Recibiendo datos de Drama en 2020, página 1
# ✅
# Recibiendo datos de Drama en 2020, página 2
# ✅
# Recibiendo datos de Drama en 2020, página 3
# ✅
# Recibiendo datos de Drama en 2020, página 4
# ✅
# Recibiendo datos de Drama en 2020, página 5
# ✅
# Recibiendo datos de Drama en 2020, página 6
# ✅
# Recibiendo datos de Drama en 2020, página 7
# ✅
# Recibiendo datos de Drama en 2020, página 8
# ✅
# Recibiendo datos de Drama en 2020, página 9
# ✅
# Recibiendo datos de Drama en 2020, página 10
# ✅
# Recibiendo datos de Drama en 2020, página 11
# ✅
# Recibiendo datos de Drama en 2020, página 12
# ✅
# Recibiendo datos de Drama en 2020, página 13
# ✅
# Recibiendo datos de Drama en 2020, página 14
# ✅
# Recibiendo datos de Drama en 2020, página 15
# ✅
# Recibiendo datos de Drama en 2020, página 16
# ✅
# Recibiendo datos de Drama en 2020, página 17
# ✅
# Recibiendo datos de Drama en 2020, página 18
# ✅
# Recibiendo datos de Drama en 2020, página 19
# ✅
# Recibiendo datos de Drama en 2020, página 20
# ✅
# Recibiendo datos de Drama en 2020, página 21
# ✅
# Recibiendo datos de Drama en 2020, página 22
# ✅
# Recibiendo datos de Drama en 2020, página 23
# ✅
# Recibiendo datos de Drama en 2020, página 24
# ✅
# Recibiendo datos de Drama en 2020, página 25
# ✅
# Recibiendo datos de Drama en 2020, página 26
# ✅
# Recibiendo datos de Drama en 2020, página 27
# ✅
# Recibiendo datos de Drama en 2020, página 28
# ✅
# Recibiendo datos de Drama en 2020, página 29
# ✅
# Recibiendo datos de Drama en 2020, página 30
# ✅
# Recibiendo datos de Drama en 2020, página 31
# ✅
# Recibiendo datos de Drama en 2020, página 32
# ✅
# Recibiendo datos de Drama en 2020, página 33
# ✅
# Recibiendo datos de Drama en 2020, página 34
# ✅
# Recibiendo datos de Drama en 2020, página 35
# ✅
# Recibiendo datos de Drama en 2020, página 36
# ✅
# Recibiendo datos de Drama en 2020, página 37
# ✅
# Recibiendo datos de Drama en 2020, página 38
# ✅
# Recibiendo datos de Drama en 2020, página 39
# ✅
# Recibiendo datos de Drama en 2020, página 40
# ✅
# Recibiendo datos de Drama en 2020, página 41
# ✅
# Recibiendo datos de Drama en 2020, página 42
# ✅
# Recibiendo datos de Drama en 2020, página 43
# ✅
# Recibiendo datos de Drama en 2020, página 44
# ✅
# Recibiendo datos de Drama en 2020, página 45
# ✅
# Recibiendo datos de Drama en 2020, página 46
# ✅
# Recibiendo datos de Drama en 2020, página 47
# ✅
# Recibiendo datos de Drama en 2020, página 48
# ✅
# Recibiendo datos de Drama en 2020, página 49
# ✅
# Recibiendo datos de Drama en 2020, página 50
# ✅
# Recibiendo datos de Drama en 2021, página 1
# ✅
# Recibiendo datos de Drama en 2021, página 2
# ✅
# Recibiendo datos de Drama en 2021, página 3
# ✅
# Recibiendo datos de Drama en 2021, página 4
# ✅
# Recibiendo datos de Drama en 2021, página 5
# ✅
# Recibiendo datos de Drama en 2021, página 6
# ✅
# Recibiendo datos de Drama en 2021, página 7
# ✅
# Recibiendo datos de Drama en 2021, página 8
# ✅
# Recibiendo datos de Drama en 2021, página 9
# ✅
# Recibiendo datos de Drama en 2021, página 10
# ✅
# Recibiendo datos de Drama en 2021, página 11
# ✅
# Recibiendo datos de Drama en 2021, página 12
# ✅
# Recibiendo datos de Drama en 2021, página 13
# ✅
# Recibiendo datos de Drama en 2021, página 14
# ✅
# Recibiendo datos de Drama en 2021, página 15
# ✅
# Recibiendo datos de Drama en 2021, página 16
# ✅
# Recibiendo datos de Drama en 2021, página 17
# ✅
# Recibiendo datos de Drama en 2021, página 18
# ✅
# Recibiendo datos de Drama en 2021, página 19
# ✅
# Recibiendo datos de Drama en 2021, página 20
# ✅
# Recibiendo datos de Drama en 2021, página 21
# ✅
# Recibiendo datos de Drama en 2021, página 22
# ✅
# Recibiendo datos de Drama en 2021, página 23
# ✅
# Recibiendo datos de Drama en 2021, página 24
# ✅
# Recibiendo datos de Drama en 2021, página 25
# ✅
# Recibiendo datos de Drama en 2021, página 26
# ✅
# Recibiendo datos de Drama en 2021, página 27
# ✅
# Recibiendo datos de Drama en 2021, página 28
# ✅
# Recibiendo datos de Drama en 2021, página 29
# ✅
# Recibiendo datos de Drama en 2021, página 30
# ✅
# Recibiendo datos de Drama en 2021, página 31
# ✅
# Recibiendo datos de Drama en 2021, página 32
# ✅
# Recibiendo datos de Drama en 2021, página 33
# ✅
# Recibiendo datos de Drama en 2021, página 34
# ✅
# Recibiendo datos de Drama en 2021, página 35
# ✅
# Recibiendo datos de Drama en 2021, página 36
# ✅
# Recibiendo datos de Drama en 2021, página 37
# ✅
# Recibiendo datos de Drama en 2021, página 38
# ✅
# Recibiendo datos de Drama en 2021, página 39
# ✅
# Recibiendo datos de Drama en 2021, página 40
# ✅
# Recibiendo datos de Drama en 2021, página 41
# ✅
# Recibiendo datos de Drama en 2021, página 42
# ✅
# Recibiendo datos de Drama en 2021, página 43
# ✅
# Recibiendo datos de Drama en 2021, página 44
# ✅
# Recibiendo datos de Drama en 2021, página 45
# ✅
# Recibiendo datos de Drama en 2021, página 46
# ✅
# Recibiendo datos de Drama en 2021, página 47
# ✅
# Recibiendo datos de Drama en 2021, página 48
# ✅
# Recibiendo datos de Drama en 2021, página 49
# ✅
# Recibiendo datos de Drama en 2021, página 50
# ✅
# Recibiendo datos de Drama en 2022, página 1
# ✅
# Recibiendo datos de Drama en 2022, página 2
# ✅
# Recibiendo datos de Drama en 2022, página 3
# ✅
# Recibiendo datos de Drama en 2022, página 4
# ✅
# Recibiendo datos de Drama en 2022, página 5
# ✅
# Recibiendo datos de Drama en 2022, página 6
# ✅
# Recibiendo datos de Drama en 2022, página 7
# ✅
# Recibiendo datos de Drama en 2022, página 8
# ✅
# Recibiendo datos de Drama en 2022, página 9
# ✅
# Recibiendo datos de Drama en 2022, página 10
# ✅
# Recibiendo datos de Drama en 2022, página 11
# ✅
# Recibiendo datos de Drama en 2022, página 12
# ✅
# Recibiendo datos de Drama en 2022, página 13
# ✅
# Recibiendo datos de Drama en 2022, página 14
# ✅
# Recibiendo datos de Drama en 2022, página 15
# ✅
# Recibiendo datos de Drama en 2022, página 16
# ✅
# Recibiendo datos de Drama en 2022, página 17
# ✅
# Recibiendo datos de Drama en 2022, página 18
# ✅
# Recibiendo datos de Drama en 2022, página 19
# ✅
# Recibiendo datos de Drama en 2022, página 20
# ✅
# Recibiendo datos de Drama en 2022, página 21
# ✅
# Recibiendo datos de Drama en 2022, página 22
# ✅
# Recibiendo datos de Drama en 2022, página 23
# ✅
# Recibiendo datos de Drama en 2022, página 24
# ✅
# Recibiendo datos de Drama en 2022, página 25
# ✅
# Recibiendo datos de Drama en 2022, página 26
# ✅
# Recibiendo datos de Drama en 2022, página 27
# ✅
# Recibiendo datos de Drama en 2022, página 28
# ✅
# Recibiendo datos de Drama en 2022, página 29
# ✅
# Recibiendo datos de Drama en 2022, página 30
# ✅
# Recibiendo datos de Drama en 2022, página 31
# ✅
# Recibiendo datos de Drama en 2022, página 32
# ✅
# Recibiendo datos de Drama en 2022, página 33
# ✅
# Recibiendo datos de Drama en 2022, página 34
# ✅
# Recibiendo datos de Drama en 2022, página 35
# ✅
# Recibiendo datos de Drama en 2022, página 36
# ✅
# Recibiendo datos de Drama en 2022, página 37
# ✅
# Recibiendo datos de Drama en 2022, página 38
# ✅
# Recibiendo datos de Drama en 2022, página 39
# ✅
# Recibiendo datos de Drama en 2022, página 40
# ✅
# Recibiendo datos de Drama en 2022, página 41
# ✅
# Recibiendo datos de Drama en 2022, página 42
# ✅
# Recibiendo datos de Drama en 2022, página 43
# ✅
# Recibiendo datos de Drama en 2022, página 44
# ✅
# Recibiendo datos de Drama en 2022, página 45
# ✅
# Recibiendo datos de Drama en 2022, página 46
# ✅
# Recibiendo datos de Drama en 2022, página 47
# ✅
# Recibiendo datos de Drama en 2022, página 48
# ✅
# Recibiendo datos de Drama en 2022, página 49
# ✅
# Recibiendo datos de Drama en 2022, página 50
# ✅
# Recibiendo datos de Drama en 2023, página 1
# ✅
# Recibiendo datos de Drama en 2023, página 2
# ✅
# Recibiendo datos de Drama en 2023, página 3
# ✅
# Recibiendo datos de Drama en 2023, página 4
# ✅
# Recibiendo datos de Drama en 2023, página 5
# ✅
# Recibiendo datos de Drama en 2023, página 6
# ✅
# Recibiendo datos de Drama en 2023, página 7
# ✅
# Recibiendo datos de Drama en 2023, página 8
# ✅
# Recibiendo datos de Drama en 2023, página 9
# ✅
# Recibiendo datos de Drama en 2023, página 10
# ✅
# Recibiendo datos de Drama en 2023, página 11
# ✅
# Recibiendo datos de Drama en 2023, página 12
# ✅
# Recibiendo datos de Drama en 2023, página 13
# ✅
# Recibiendo datos de Drama en 2023, página 14
# ✅
# Recibiendo datos de Drama en 2023, página 15
# ✅
# Recibiendo datos de Drama en 2023, página 16
# ✅
# Recibiendo datos de Drama en 2023, página 17
# ✅
# Recibiendo datos de Drama en 2023, página 18
# ✅
# Recibiendo datos de Drama en 2023, página 19
# ✅
# Recibiendo datos de Drama en 2023, página 20
# ✅
# Recibiendo datos de Drama en 2023, página 21
# ✅
# Recibiendo datos de Drama en 2023, página 22
# ✅
# Recibiendo datos de Drama en 2023, página 23
# ✅
# Recibiendo datos de Drama en 2023, página 24
# ✅
# Recibiendo datos de Drama en 2023, página 25
# ✅
# Recibiendo datos de Drama en 2023, página 26
# ✅
# Recibiendo datos de Drama en 2023, página 27
# ✅
# Recibiendo datos de Drama en 2023, página 28
# ✅
# Recibiendo datos de Drama en 2023, página 29
# ✅
# Recibiendo datos de Drama en 2023, página 30
# ✅
# Recibiendo datos de Drama en 2023, página 31
# ✅
# Recibiendo datos de Drama en 2023, página 32
# ✅
# Recibiendo datos de Drama en 2023, página 33
# ✅
# Recibiendo datos de Drama en 2023, página 34
# ✅
# Recibiendo datos de Drama en 2023, página 35
# ✅
# Recibiendo datos de Drama en 2023, página 36
# ✅
# Recibiendo datos de Drama en 2023, página 37
# ✅
# Recibiendo datos de Drama en 2023, página 38
# ✅
# Recibiendo datos de Drama en 2023, página 39
# ✅
# Recibiendo datos de Drama en 2023, página 40
# ✅
# Recibiendo datos de Drama en 2023, página 41
# ✅
# Recibiendo datos de Drama en 2023, página 42
# ✅
# Recibiendo datos de Drama en 2023, página 43
# ✅
# Recibiendo datos de Drama en 2023, página 44
# ✅
# Recibiendo datos de Drama en 2023, página 45
# ✅
# Recibiendo datos de Drama en 2023, página 46
# ✅
# Recibiendo datos de Drama en 2023, página 47
# ✅
# Recibiendo datos de Drama en 2023, página 48
# ✅
# Recibiendo datos de Drama en 2023, página 49
# ✅
# Recibiendo datos de Drama en 2023, página 50
# ✅
# Recibiendo datos de Drama en 2024, página 1
# ✅
# Recibiendo datos de Drama en 2024, página 2
# ✅
# Recibiendo datos de Drama en 2024, página 3
# ✅
# Recibiendo datos de Drama en 2024, página 4
# ✅
# Recibiendo datos de Drama en 2024, página 5
# ✅
# Recibiendo datos de Drama en 2024, página 6
# ✅
# Recibiendo datos de Drama en 2024, página 7
# ✅
# Recibiendo datos de Drama en 2024, página 8
# ✅
# Recibiendo datos de Drama en 2024, página 9
# ✅
# Recibiendo datos de Drama en 2024, página 10
# ✅
# Recibiendo datos de Drama en 2024, página 11
# ✅
# Recibiendo datos de Drama en 2024, página 12
# ✅
# Recibiendo datos de Drama en 2024, página 13
# ✅
# Recibiendo datos de Drama en 2024, página 14
# ✅
# Recibiendo datos de Drama en 2024, página 15
# ✅
# Recibiendo datos de Drama en 2024, página 16
# ✅
# Recibiendo datos de Drama en 2024, página 17
# ✅
# Recibiendo datos de Drama en 2024, página 18
# ✅
# Recibiendo datos de Drama en 2024, página 19
# ✅
# Recibiendo datos de Drama en 2024, página 20
# ✅
# Recibiendo datos de Drama en 2024, página 21
# ✅
# Recibiendo datos de Drama en 2024, página 22
# ✅
# Recibiendo datos de Drama en 2024, página 23
# ✅
# Recibiendo datos de Drama en 2024, página 24
# ✅
# Recibiendo datos de Drama en 2024, página 25
# ✅
# Recibiendo datos de Drama en 2024, página 26
# ✅
# Recibiendo datos de Drama en 2024, página 27
# ✅
# Recibiendo datos de Drama en 2024, página 28
# ✅
# Recibiendo datos de Drama en 2024, página 29
# ✅
# Recibiendo datos de Drama en 2024, página 30
# ✅
# Recibiendo datos de Drama en 2024, página 31
# ✅
# Recibiendo datos de Drama en 2024, página 32
# ✅
# Recibiendo datos de Drama en 2024, página 33
# ✅
# Recibiendo datos de Drama en 2024, página 34
# ✅
# Recibiendo datos de Drama en 2024, página 35
# ✅
# Recibiendo datos de Drama en 2024, página 36
# ✅
# Recibiendo datos de Drama en 2024, página 37
# ✅
# Recibiendo datos de Drama en 2024, página 38
# ✅
# Recibiendo datos de Drama en 2024, página 39
# ✅
# Recibiendo datos de Drama en 2024, página 40
# ✅
# Recibiendo datos de Drama en 2024, página 41
# ✅
# Recibiendo datos de Drama en 2024, página 42
# ✅
# Recibiendo datos de Drama en 2024, página 43
# ✅
# Recibiendo datos de Drama en 2024, página 44
# ✅
# Recibiendo datos de Drama en 2024, página 45
# ✅
# Recibiendo datos de Drama en 2024, página 46
# ✅
# Recibiendo datos de Drama en 2024, página 47
# ✅
# Recibiendo datos de Drama en 2024, página 48
# ✅
# Recibiendo datos de Drama en 2024, página 49
# ✅
# Recibiendo datos de Drama en 2024, página 50
# ✅
# Recibiendo datos de Drama en 2025, página 1
# ✅
# Recibiendo datos de Drama en 2025, página 2
# ✅
# Recibiendo datos de Drama en 2025, página 3
# ✅
# Recibiendo datos de Drama en 2025, página 4
# ✅
# Recibiendo datos de Drama en 2025, página 5
# ✅
# Recibiendo datos de Drama en 2025, página 6
# ✅
# Recibiendo datos de Drama en 2025, página 7
# ✅
# Recibiendo datos de Drama en 2025, página 8
# ✅
# Recibiendo datos de Drama en 2025, página 9
# ✅
# Recibiendo datos de Drama en 2025, página 10
# ✅
# Recibiendo datos de Drama en 2025, página 11
# ✅
# Recibiendo datos de Drama en 2025, página 12
# ✅
# Recibiendo datos de Drama en 2025, página 13
# ✅
# Recibiendo datos de Drama en 2025, página 14
# ✅
# Recibiendo datos de Drama en 2025, página 15
# ✅
# Recibiendo datos de Drama en 2025, página 16
# ✅
# Recibiendo datos de Drama en 2025, página 17
# ✅
# Recibiendo datos de Drama en 2025, página 18
# ✅
# Recibiendo datos de Drama en 2025, página 19
# ✅
# Recibiendo datos de Drama en 2025, página 20
# ✅
# Recibiendo datos de Drama en 2025, página 21
# ✅
# Recibiendo datos de Drama en 2025, página 22
# ✅
# Recibiendo datos de Drama en 2025, página 23
# ✅
# Recibiendo datos de Drama en 2025, página 24
# ✅
# Recibiendo datos de Drama en 2025, página 25
# ✅
# Recibiendo datos de Drama en 2025, página 26
# ✅
# Recibiendo datos de Drama en 2025, página 27
# ✅
# Recibiendo datos de Drama en 2025, página 28
# ✅
# Recibiendo datos de Drama en 2025, página 29
# ✅
# Recibiendo datos de Drama en 2025, página 30
# ✅
# Recibiendo datos de Drama en 2025, página 31
# ✅
# Recibiendo datos de Drama en 2025, página 32
# ✅
# Recibiendo datos de Drama en 2025, página 33
# ✅
# Recibiendo datos de Drama en 2025, página 34
# ✅
# Recibiendo datos de Drama en 2025, página 35
# ✅
# Recibiendo datos de Drama en 2025, página 36
# ✅
# Recibiendo datos de Drama en 2025, página 37
# ✅
# Recibiendo datos de Drama en 2025, página 38
# ✅
# Recibiendo datos de Drama en 2025, página 39
# ✅
# Recibiendo datos de Drama en 2025, página 40
# ✅
# Recibiendo datos de Drama en 2025, página 41
# ✅
# Recibiendo datos de Drama en 2025, página 42
# ✅
# Recibiendo datos de Drama en 2025, página 43
# ✅
# Recibiendo datos de Drama en 2025, página 44
# ✅
# Recibiendo datos de Drama en 2025, página 45
# ✅
# Recibiendo datos de Drama en 2025, página 46
# ✅
# Recibiendo datos de Drama en 2025, página 47
# ✅
# Recibiendo datos de Drama en 2025, página 48
# ✅
# Recibiendo datos de Drama en 2025, página 49
# ✅
# Recibiendo datos de Drama en 2025, página 50
# ✅

# %%
# Crea el archivo CSV.
infiniteplay.save_to_csv(f'Películas_{genres}_{start_year}-{end_year}.csv')
